# %% [markdown]
# <a href="https://colab.research.google.com/github/spencerdailovescs/blackjack/blob/master/Copy_of_midterm2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install BeautifulSoup4 lxml
# Out:
# Requirement already satisfied: BeautifulSoup4 in /usr/local/lib/python3.6/dist-packages (4.6.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (4.2.6)

# %%
# %config InlineBackend.figure_formats = ['retina']
import json
import datetime
import requests
import numpy as np
import networkx as nx
from random import sample
from urllib.parse import urlparse
from collections import deque, defaultdict
from bs4 import BeautifulSoup
from numpy import linalg as LA

# %%
USER_AGENT = ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) '
              'Apple WebKit/537.36 (KHTML, like Gecko) '
              'Chrome/80.0.3987.149 Safari/537.36')

def unique_url(url):
    """Returns a canonical representation of a link."""
    stripped = url.replace('://www.', '://')
    stripped = stripped.replace(f'{urlparse(url).scheme}://', '').rstrip('/')
    if '#' in stripped:
      # Remove trailing anchor
      return '#'.join(stripped.split('#')[:-1])
    return stripped


def check_page(url):
    """Verifies that a URL corresponds to a reachable web page."""
    try:
        head = requests.head(url,
                             headers={'User-Agent': USER_AGENT},
                             allow_redirects=True,
                             timeout=1)
        content_type = head.headers.get('Content-Type', '').lower()
        return content_type.startswith('text/html')
    except requests.exceptions.RequestException as ex:
        # Couldn't load this particular page, for whatever reason (404, etc.)
        return False


def all_links(url):
    """Retrieves all links from a web page."""
    try:
        req = requests.get(url,
                           headers={'User-Agent': USER_AGENT},
                           allow_redirects=True,
                           timeout=5)
    except requests.exceptions.RequestException as ex:
        # Couldn't load this particular page, for whatever reason (404, etc.)
        return None

    # Get links from page.
    soup = BeautifulSoup(req.text, 'lxml')
    return [link.get('href', '') for link in soup.select('a')]


def filter_links(source_url, urls, blacklist, whitelist,
                 follow_relative_links):
    """Filters and cleans links."""
    filtered = []
    o = urlparse(source_url)
    source_scheme = o.scheme
    source_domain = o.netloc

    for href in urls:
        if not href or href.startswith('#') or \
          (not href.startswith('http') and not follow_relative_links):

            continue
        else:
            if href.startswith('//'):
                href = 'https:' + href
            elif href.startswith('/'):
                # Internal link (w.r.t. website root)
                href = f'{source_scheme}://{source_domain}{href}'
            elif not href.startswith('http'):
                # Internal link (w.r.t. current link)
                href = source_url.rstrip('/') + '/' + href
        if '#' in href:
            href = '#'.join(href.split('#')[:-1]) # strip anchor

        # Blacklist/whitelist filtering.
        blacklisted = False
        whitelisted = False
        for keyword in blacklist:
            if keyword.lower() in href.lower():
                blacklisted = True
                break
        for keyword in whitelist:
            if keyword.lower() in href.lower():
                whitelisted = True
                break
        if ((whitelist and whitelisted) or not whitelist) and \
           ((blacklist and not blacklisted) or not blacklist) and \
           'mailto:' not in href and 'javascript:' not in href:
            filtered.append(href)
    return filtered


def crawl(start_url,
          save_file,
          n,
          verbose=True,
          follow_relative_links=True,
          max_links_per_page=None,
          blacklist=None,
          whitelist=None):
    """Crawls pages starting from a given URL and saves the link graph.

    :param start_url: The starting URL.
    :param save_file: The JSON file to save crawl data to.
    :param n: The number of pages to add to the graph. Pages in the graph have
        not necessarily been visited (such pages never have outlinks).
    :param verbose: Determines whether to print URLs as they are crawled.
    :param follow_relative_links: Determines whether to follow relative links.
        Following relative links tends to result in narrow, deep crawl--many
        pages being crawled on a relatively small number of websites.
    :param max_links_per_page: The number of links to add to the link queue
        per page. (For each page, the order of links is always shuffled.)
    :param blacklist: A blacklist of URL keywords. If any keyword on the
        blacklist appears in a URL, it will be excluded from the graph and
        not crawled.
    :param whitelist: A whitelist of URL keywords. If the whitelist is nonempty,
        a URL will only be included in the graph and crawled if at least one
        keyword from the whitelist is included in it. The whitelist can be
        combined with the blacklist for highly detailed URL filtering.
    """
    enqueued = set([unique_url(start_url)])
    dead = set([])
    link_graph = []
    link_queue = deque([start_url])
    ts = datetime.datetime.now().replace(microsecond=0).isoformat()
    if max_links_per_page is None:
        max_links_per_page = float('inf')
    if blacklist is None:
        blacklist = []
    if whitelist is None:
        whitelist = []

    while link_queue and len(enqueued) < n:
        curr_link = link_queue.popleft()
        if verbose:
            print(curr_link)

        # Fetch page metadata and text.
        if not check_page(curr_link):
            # Page not reachable or content type incorrect
            dead.add(curr_link)
            continue
        links = all_links(curr_link)
        if links is None:
            # GET request failed
            dead.add(curr_link)
            continue

        # Filter and sample links from the page.
        filtered_links = set(filter_links(curr_link, links,
                                          blacklist, whitelist,
                                          follow_relative_links))
        new_links = [href for href in filtered_links
                     if unique_url(href) not in enqueued]
        sampled_links = sample(new_links,
                               min(max_links_per_page, len(new_links)))
        for link in filtered_links:
            link_graph.append({'from': curr_link, 'to': link})
        for link in sampled_links:
            link_queue.append(link)
            enqueued.add(unique_url(link))

    if verbose:
        print(f'Crawl finished (saw {len(enqueued)} links)')
    filtered = [link for link in link_graph
                if (unique_url(link['to']) in enqueued and 
                   link['to'] not in dead)]
    with open(save_file, 'w') as f:
        json.dump(
            {
                'start_url': start_url,
                'n': n,
                'follow_relative_links': follow_relative_links,
                'max_links_per_page': max_links_per_page,
                'timestamp': ts,
                'blacklist': blacklist,
                'whitelist': whitelist,
                'links': filtered
            }, f)

# %%
def load_crawl_graph(save_file):
  """Loads crawl data as a NetworkX directed graph."""
  with open(save_file) as f:
    crawl_data = json.load(f)
  graph = nx.DiGraph()
  graph.add_edges_from([(link['from'], link['to'])
                        for link in crawl_data['links']])
  for node in graph.nodes:
    graph.nodes[node]['url'] = node
  graph = nx.relabel_nodes(graph,
                           {url: idx for idx, url in enumerate(graph.nodes)})
  return graph

# %%
crawl('https://www.pokemon.com/us/',
       'xkcd.json',  
        n=1000,
        follow_relative_links=True,
        max_links_per_page=20,
        blacklist=('facebook', 'messenger', 'linkedin'))  # avoid link traps
# Out:
# https://www.pokemon.com/us/
# https://www.pokemon.com/us/pokemon-news/an-april-2020-message-from-pokemon-masters-producers-yu-sasaki-and-tetsuya-iguchi/
# https://www.pokemon.com/us/pokedex/lileep
# https://www.pokemon.com/us/pokemon-episodes/
# https://www.pokemon.com/us/pokedex/ralts
# https://www.pokemon.com/us/play-pokemon/pokemon-events/pokemon-tournaments/
# https://www.pokemon.com/us/pokedex/blaziken
# https://www.pokemon.com/us/pokedex/stakataka
# https://swordshield.pokemon.com/en-us/pokemon-galar-region/zarude/
# https://caru.bbb.org/caru.aspx?id=1596150491
# https://www.pokemon.com/us/pokemon-news/tips-for-pokemon-masters-battle-villa-pokemon-gos-go-battle-league-and-more/
# https://www.pokemon.com/us/play-pokemon/pokemon-events/
# https://www.pokemon.com/us/play-pokemon/organize/
# https://www.pokemon.com/us/pokemon-news/have-quick-fun-pokemon-tcg-matches-with-sword-shield-rebel-clash-build-battle-boxes/
# https://www.pokemon.com/us/pokedex/luxio
# https://www.pokemon.com/us/play-pokemon/about/tournaments-rules-and-resources/
# https://www.twitter.com/pokemon
# https://www.pokemon.com/us/play-pokemon/pokemon-events/play-in-a-league/
# https://www.pokemon.com/us/pokemon-news/spring-into-the-pokemon-tcg-online/
# https://www.pokemon.com/us/play-pokemon/about/play-points/
# https://www.pokemon.com/us/privacy-notice/
# https://www.pokemon.com/us/pokedex/
# https://www.instagram.com/pokemon
# https://www.pokemon.com/us/play-pokemon/
# https://www.youtube.com/pokemon
# https://www.pokemon.com/us/play-pokemon/about/tournaments-glossary/
# https://www.pokemon.com/us/customer-service/
# https://www.pokemon.com/us/pokemon-distributions/
# https://www.pokemon.com/us/strategy/
# https://www.pokemon.com/us/pokemon-trainer-club/login
# https://www.pokemon.com/us/legal/
# https://www.pokemon.com/us/pokemon-video-games/all-pokemon-games/
# https://press.pokemon.com/
# https://www.pokemon.com/us/play-pokemon/about/parents-guide/
# https://www.pokemon.com/us/play-pokemon/leaderboards/
# https://www.pokemon.com/us/parents-guide/
# https://www.pokemon.com/us/cookie-page/
# https://www.pokemon.com/us/pokemon-trainer-club/my-profile/
# https://www.pokemon.com/us/pokemon-trainer-club/sign-up/
# https://www.pokemon.com/us/pokemon-trainer-club/friends/
# https://www.pokemon.com/us/pokemon-news/
# https://www.pokemon.com/us/pokemon-trainer-club/login?_rd=/us/pokedex/lileep
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/sm-series/sm12/10/
# https://www.pokemon.com/us/play-pokemon/pokemon-events/find-an-event/
# https://www.pokemon.com/us/pokemon-episodes/10_17-wild-in-the-streets/
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/ex-series/ex16/52/
# https://www.pokemon.com/us/country-region/
# https://www.pokemon.com/us/pokemon-tcg/play-online/
# https://www.pokemon.com/us/play-pokemon/about/
# https://www.pokemon.com/us/pokedex/?weakness=fighting
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/ex-series/ex2/43/
# https://www.pokemon.com/us/pokemon-tcg/play-online/leaderboards/
# https://chj.tbe.taleo.net/dispatcher/servlet/DispatcherServlet?org=POKEMON&act=redirectCws&cws=1
# https://www.pokemon.com/us/play-pokemon/pokemon-events/pokemon-tournaments/earn-championship-points/
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/ex-series/ex2/42/
# https://www.pokemon.com/us/play-pokemon/pokemon-events/pre-release-tournaments/
# https://www.pokemon.com/us/pokedex/?type=grass
# https://www.pokemon.com/us/pokemon-episodes/08_10-wheres-armaldo/
# https://www.pokemon.com/us/pokedex/?type=rock
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/bw-series/bw10/3/
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/ex-series/ex12/56/
# https://club.pokemon.com/us/pokemon-trainer-club/login
# https://www.pokemon.com/us/pokemon-episodes/pokemon-movies/
# https://www.pokemon.com/us/terms-of-use/
# https://www.pokemon.com/us/pokemon-episodes/pokemon-tv-seasons/
# https://watch.pokemon.com/en-us/season.html?id=pokemon-twilight-wings
# https://watch.pokemon.com/en-us/season.html?id=team-rockets-money-making-schemes
# https://www.pokemon.com/us/pokemon-trainer-club/play-pokemon/events/
# https://www.pokemon.com/us/pokemon-trainer-club/logout
# https://www.pokemon.com/us/pokemon-tcg/
# https://www.pokemon.com/us/about-pokemon/
# https://www.pokemon.com/us/pokemon-video-games/
# https://www.pokemon.com/us/play-pokemon/about/video-game-glossary/
# http://example.com
# https://watch.pokemon.com/en-us/
# https://www.pokemon.com/us/pokedex/?weakness=ghost
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/bw-series/bw8/59/
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/sm-series/sm8/139/
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/xy-series/xy8/100/
# https://www.pokemon.com/us/pokedex/pelipper
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/sm-series/sm3/91/
# https://www.pokemon.com/us/pokemon-trainer-club/login?_rd=/us/pokedex/ralts
# https://www.pokemon.com/us/pokedex/?weakness=steel
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/bw-series/bw11/59/
# https://www.pokemon.com/us/pokemon-episodes/09_01-fear-factor-phony/
# https://www.pokemon.com/us/pokedex/?type=psychic
# https://www.pokemon.com/us/pokedex/?type=fairy
# https://www.pokemon.com/us/pokemon-episodes/09_15-harley-rides-again/
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/xy-series/xy7/52/
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/bw-series/bw11/RC8/
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/xy-series/xy8/68/
# https://www.pokemon.com/us/pokedex/gallade
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/sm-series/sma/SV34/
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/sm-series/sm12/80/
# https://www.pokemon.com/us/pokemon-news/2020-season-pokemon-tcg-format-rotation/
# https://www.pokemon.com/us/pokemon-tcg/sun-moon-ultra-prism/explore-and-watch/
# https://www.pokemon.com/us/play-pokemon/organize/host-play-pokemon-events/
# https://www.pokemon.com/us/play-pokemon/organize/start-a-league/
# https://www.pokemon.com/us/play-pokemon/pokemon-events/pokemon-tournaments/midseason-showdown/
# https://www.pokemon.com/us/play-pokemon/pokemon-events/pokemon-tournaments/vg-premier-challenge/
# https://www.pokemon.com/us/pokemon-video-games/pokemon-sword-and-pokemon-shield/
# https://www.pokemon.com/us/account/
# https://www.pokemon.com/us/play-pokemon/organize/become-a-professor/
# https://www.pokemon.com/us/play-pokemon/organize/event-requirements/
# https://www.pokemon.com/us/pokemon-news/2019-season-pokemon-tcg-format-rotation/
# https://www.pokemon.com/us/play-pokemon/pokemon-events/pokemon-tournaments/international-championships/
# https://www.pokemon.com/us/pokemon-video-games/pokemon-ultra-sun-and-pokemon-ultra-moon/
# https://www.pokemon.com/us/play-pokemon/pokemon-events/pokemon-tournaments/tcg-league-cup/
# https://www.pokemon.com/us/play-pokemon/organize/become-a-professor/professor-cup/
# https://www.pokemon.com/us/play-pokemon/pokemon-events/pokemon-tournaments/special-events/
# https://www.pokemon.com/us/play-pokemon/worlds/2019/about/
# https://www.pokemon.com/us/play-pokemon/pokemon-events/pokemon-tournaments/pokemon-world-championships/
# https://www.pokemon.com/us/play-pokemon/pokemon-events/pokemon-tournaments/tcg-league-challenge/
# https://www.pokemon.com/us/pokemon-news/2020-pokemon-championship-series-canceled/
# https://www.pokemon.com/us/pokemon-episodes/17_02-lumiose-city-pursuit/
# https://www.pokemon.com/us/pokedex/?weakness=ground
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/xy-series/xyp/XY86/
# https://www.pokemon.com/us/pokemon-episodes/09_46-once-more-with-reeling/
# https://www.pokemon.com/us/pokemon-episodes/17_10-mega-mega-meowth-madness/
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/ex-series/ex1/15/
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/sm-series/sm7/153/
# https://www.pokemon.com/us/pokedex/?weakness=water
# https://www.pokemon.com/us/pokedex/combusken
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/xy-series/xy3/14/
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/xy-series/xy5/28/
# https://www.pokemon.com/us/pokedex/?weakness=flying
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/xy-series/xyp/XY54/
# https://www.pokemon.com/us/pokemon-episodes/06_09-play-with-fire/
# https://www.pokemon.com/us/pokedex/?type=fighting
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/sm-series/sm7/170/
# https://www.pokemon.com/us/pokemon-episodes/09_47-home-is-where-the-start-is/
# https://www.pokemon.com/us/pokemon-trainer-club/login?_rd=/us/pokedex/blaziken
# https://www.pokemon.com/us/pokemon-episodes/19_39-a-towering-takeover/
# https://www.pokemon.com/us/pokedex/?weakness=psychic
# https://www.pokemon.com/us/pokedex/blacephalon
# https://www.pokemon.com/us/pokedex/?type=steel
# https://www.pokemon.com/us/pokedex/naganadel
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/sm-series/sm7/159/
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/sm-series/smp/SM209/
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/sm-series/smp/SM180/
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/sm-series/sm7/102/
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/sm-series/sma/SV74/
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/sm-series/sm7/176/
# https://www.pokemon.com/us/pokemon-trainer-club/login?_rd=/us/pokedex/stakataka
# https://www.pokemon.com/us/pokemon-tcg/pokemon-cards/sm-series/sm10/106/
# https://swordshield.pokemon.com/en-us/pokemon-galar-region/zarude/../eldegoss/
# https://swordshield.pokemon.com/en-us/pokemon-galar-region/zarude/../gigantamax-charizard/
# https://club.pokemon.com/us/pokemon-trainer-club/sign-up/
# https://swordshield.pokemon.com/en-us/gameplay/pokejobs/
# Crawl finished (saw 1013 links)

# %%
 crawl('https://en.wikipedia.org/wiki/Group_theory',
       'wiki_math.json',
        n=4000,
        follow_relative_links=True,
        max_links_per_page=20,
        whitelist=('en.wikipedia.org/wiki/',),
        blacklist=('special:', 'talk:', 'user:', 'portal:',
                   'help:', 'category:', 'wikipedia:', 'file:'))

# %%
graph = load_crawl_graph('xkcd.json')  # or whichever JSON you want to build a graph from
A = nx.adjacency_matrix(graph).todense()

M = A.astype(float)

p = 1
rows = len(A)
columns = rows

#for each row
for x in range (0, rows):
  total = 0

  #get sum
  for y in range (0, columns):
    total = total + A[x, y]
  
  #divide by sum
  for y in range (0, columns):
    if total == 0:
      M[x,y] = 1 / columns
    elif A[x,y] == 1:
      M[x,y] = ((1 / total) - (p / total) + (p / columns))
    else:
      M[x,y] = (p/columns)

#ensures that each row is stochastic
# for x in range(0, rows):
#   total = 0
#   for y in range(0, columns):
#     total = total + M[x, y]
#   print(total)

#iteration matrix
iterate = M.transpose()

#power method
initial = np.zeros((rows, 1))
initial[0, 0] = 1

iterations = 0
while initial[0,0] != (np.matmul(iterate, initial))[0,0]:
  iterations = iterations + 1
  initial = np.matmul(iterate, initial)

print("Iterations:")
print(iterations)

#get the max eigenvector
evals, evecs = LA.eig(iterate)
evecmax = np.argmax(evals)
eigenvector = np.round(np.real(evecs[evecmax] ),6)


#score of top website
index = (np.argmax(initial))
score = initial[index]
print("score:", score)


#most important websites
print("urls according to power method:")
for x in range (0, 10):
  index = (np.argmax(initial))
  initial[index] = 0
  print(graph.nodes[index])

print("urls according to eigenvalues/eigenvectors method:")
for x in range (0, 10):
  index2 = (np.argmax(eigenvector))
  eigenvector[0, index2] = 0
  print(graph.nodes[index2])
# Out:
# Iterations:
# 3
# score: [[0.00095238]]
# urls according to power method:
# {'url': 'https://www.pokemon.com/us/'}
# {'url': 'https://www.pokemon.com/us/pokedex/stakataka'}
# {'url': 'https://www.pokemon.com/us/play-pokemon/organize/'}
# {'url': 'https://www.pokemon.com/us/play-pokemon/pokemon-events/'}
# {'url': 'https://www.pokemon.com/us/pokemon-news/spring-into-the-pokemon-tcg-online/'}
# {'url': 'https://www.pokemon.com/us/pokemon-news/tips-for-pokemon-masters-battle-villa-pokemon-gos-go-battle-league-and-more/'}
# {'url': 'https://www.pokemon.com/us/pokemon-news/get-tips-for-max-raid-battles-the-wild-area-and-more-for-pokemon-sword-and-pokemon-shield/'}
# {'url': 'https://www.pokemon.com/us/play-pokemon/about/video-game-glossary/'}
# {'url': 'https://www.pokemon.com/us/country-region/'}
# {'url': 'https://www.youtube.com/pokemon'}
# urls according to eigenvalues/eigenvectors method:
# {'url': 'https://www.pokemon.com/us/pokedex/stakataka'}
# {'url': 'https://www.pokemon.com/us/pokedex/stakataka'}
# {'url': 'https://www.pokemon.com/us/pokedex/stakataka'}
# {'url': 'https://www.pokemon.com/us/pokedex/stakataka'}
# {'url': 'https://www.pokemon.com/us/pokedex/stakataka'}
# {'url': 'https://www.pokemon.com/us/pokedex/stakataka'}
# {'url': 'https://www.pokemon.com/us/pokedex/stakataka'}
# {'url': 'https://www.pokemon.com/us/pokedex/stakataka'}
# {'url': 'https://www.pokemon.com/us/pokedex/stakataka'}
# {'url': 'https://www.pokemon.com/us/pokedex/stakataka'}

# %%
options = {
    'node_color': 'red',
    'node_size': 8,
}
nx.draw(graph, **options)   # there are lots of ways to visualize graphs and do graph statistics in NetworkX
